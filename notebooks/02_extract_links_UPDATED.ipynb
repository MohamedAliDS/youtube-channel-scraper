# %% [markdown]
# # 02 - Extract Social Media Links from Channels
#
# **Objective:** Extract social media links (Instagram, Twitter, TikTok, Discord, etc.) from YouTube channel About sections.
#
# ## Overview
#
# This notebook:
# 1. Reads channel URLs from Excel output from Notebook 01
# 2. Visits each channel's About page
# 3. Extracts and normalizes social media links
# 4. Pivots data so each channel is one row with platform columns
# 5. Saves results to Excel
#
# ## Setup

# %%
# Import required libraries
import sys
from pathlib import Path
import pandas as pd
import logging

# Add src directory to path
src_dir = Path.cwd() / 'src'
sys.path.insert(0, str(src_dir))

# Import custom modules - FIXED VERSION
from data_processor_COMPLETE_FIXED import setup_logging, DataProcessor
from youtube_scraper_COMPLETE_FIXED import YouTubeScraper
import config_UPDATED

# Setup logging
setup_logging("INFO")
logger = logging.getLogger(__name__)

print("[OK] All imports successful!")
print(f"[INFO] Using {config_UPDATED.MAX_WORKERS} workers for scraping")
print(f"[INFO] Max retries: {config_UPDATED.MAX_RETRIES}")
# Out:
# [INFO] Configuration loaded successfully
# [INFO] Max workers: 6
# [INFO] Headless mode: True
# [INFO] UTF-8 encoding: True
# [OK] All imports successful!
# [INFO] Using 6 workers for scraping
# [INFO] Max retries: 3

# %% [markdown]
# ## Step 1: Load Channel URLs
#
# Read the channel URLs from the output of Notebook 01 (channelsfound.xlsx).

# %%
# Read the channelsfound.xlsx file
channels_file = input("Enter path to channelsfound.xlsx file: ").strip().strip('"')

df_channels = pd.read_excel(channels_file)

# Filter out channels that weren't found
channel_urls = df_channels[df_channels['channel_url'] != 'Not Found']['channel_url'].tolist()

print(f"[OK] Loaded {len(channel_urls)} valid channel URLs")
print(f"[INFO] First 5 channels:")
for url in channel_urls[:5]:
    print(f"  - {url}")
# Out:
# Enter path to channelsfound.xlsx file:  C:\Users\ArabTech\02_youtube_channel_scraper\data\processed\channels_found.xlsx
# [OK] Loaded 100 valid channel URLs
# [INFO] First 5 channels:
#   - https://www.youtube.com/@Aymanelgndy_999
#   - https://www.youtube.com/@anowyt
#   - https://www.youtube.com/@CallMePearlX
#   - https://www.youtube.com/@dzairtubetv4557
#   - https://www.youtube.com/@IhabSouda-b3q

# %% [markdown]
# ## Step 2: Initialize Scraper
#
# Create a scraper instance for extracting social media links.
#
# **Note:** Link extraction uses fewer workers (3-4) because it's more complex than channel search.

# %%
# Initialize scraper - use fewer workers for link extraction
scraper = YouTubeScraper(max_workers=3, headless=True)

print(f"[OK] YouTubeScraper initialized for link extraction")
print(f"[INFO] Workers: 3 (fewer than channel search for stability)")
print(f"[INFO] Note: Link extraction is slower than channel search")
print(f"[INFO] Expected time: 10-20 minutes for 100 channels")
# Out:
# [INFO] 2025-12-05 20:48:35 - youtube_scraper_COMPLETE_FIXED - [OK] YouTubeScraper initialized with 3 workers
# [OK] YouTubeScraper initialized for link extraction
# [INFO] Workers: 3 (fewer than channel search for stability)
# [INFO] Note: Link extraction is slower than channel search
# [INFO] Expected time: 10-20 minutes for 100 channels

# %% [markdown]
# ## Step 3: Extract Social Media Links
#
# This step will visit each channel's About page and extract links to:
# - Instagram
# - TikTok
# - X (Twitter)
# - Facebook
# - Discord
# - Telegram
# - YouTube Channels
# - Email addresses
#
# ⚠️ **This process is slower than channel search. Progress will update as channels are processed.**

# %%
# Extract social media links from all channels
print("[INFO] Extracting social media links...")
print(f"[INFO] Processing {len(channel_urls)} channels...")

all_results = scraper.extract_social_links(channel_urls)

print(f"[OK] Link extraction completed!")
print(f"[INFO] Total links found: {len(all_results)}")
# Out:
# [INFO] Extracting social media links...
# [INFO] Processing 100 channels...
# [INFO] 2025-12-05 20:48:46 - youtube_scraper_COMPLETE_FIXED - [INFO] Starting link extraction with 3 workers
# [INFO] 2025-12-05 20:48:46 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:48:46 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:48:46 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:48:47 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:48:47 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:48:47 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:48:47 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:48:47 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:48:47 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:48:47 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:48:48 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:48:48 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:48:49 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:48:49 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@CallMePearlX/featured
# [INFO] 2025-12-05 20:48:49 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:48:49 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@Aymanelgndy_999/featured
# [INFO] 2025-12-05 20:48:49 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:48:49 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@anowyt/featured
# [INFO] 2025-12-05 20:49:11 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@anowyt/about
# [INFO] 2025-12-05 20:49:13 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@CallMePearlX/about
# [INFO] 2025-12-05 20:49:14 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@Aymanelgndy_999/about
# [INFO] 2025-12-05 20:49:15 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 1 links from https://www.youtube.com/@CallMePearlX
# [INFO] 2025-12-05 20:49:17 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:49:17 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:49:18 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:19 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:19 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:49:20 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:49:20 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@dzairtubetv4557/featured
# [INFO] 2025-12-05 20:49:22 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 0 links from https://www.youtube.com/@anowyt
# [INFO] 2025-12-05 20:49:25 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:49:25 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:49:25 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:26 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:26 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:49:27 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 0 links from https://www.youtube.com/@Aymanelgndy_999
# [INFO] 2025-12-05 20:49:28 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:49:28 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@IhabSouda-b3q/featured
# [INFO] 2025-12-05 20:49:29 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:49:29 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:49:30 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:30 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:31 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:49:32 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:49:32 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@BilalFadili/featured
# [INFO] 2025-12-05 20:49:43 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@dzairtubetv4557/about
# [INFO] 2025-12-05 20:49:47 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 3 links from https://www.youtube.com/@dzairtubetv4557
# [ERROR] 2025-12-05 20:49:47 - selenium_utils_COMPLETE - [ERROR] Failed to click element: Message:
#
# [INFO] 2025-12-05 20:49:48 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@BilalFadili/about
# [INFO] 2025-12-05 20:49:49 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:49:49 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:49:50 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:51 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:51 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:49:51 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@IhabSouda-b3q/about
# [INFO] 2025-12-05 20:49:52 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 4 links from https://www.youtube.com/@BilalFadili
# [INFO] 2025-12-05 20:49:52 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:49:52 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@AfinouGamingDZ/featured
# [INFO] 2025-12-05 20:49:54 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:49:54 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:49:55 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:56 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:49:56 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:49:57 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@AfinouGamingDZ/about
# [INFO] 2025-12-05 20:49:57 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:49:57 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@mayo_sha/featured
# [INFO] 2025-12-05 20:50:02 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 8 links from https://www.youtube.com/@AfinouGamingDZ
# [INFO] 2025-12-05 20:50:04 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 0 links from https://www.youtube.com/@IhabSouda-b3q
# [INFO] 2025-12-05 20:50:05 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:50:05 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:50:06 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:50:06 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:50:06 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:50:07 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:50:07 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:50:07 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:50:07 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@Dapokir_Trendismer/featured
# [INFO] 2025-12-05 20:50:08 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:50:09 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:50:09 - WDM - Driver [C:\Users\ArabTech\.wdm\drivers\chromedriver\win64\134.0.6998.165\chromedriver-win32/chromedriver.exe] found in cache
# [INFO] 2025-12-05 20:50:10 - selenium_utils_COMPLETE - [OK] Chrome driver created successfully
# [INFO] 2025-12-05 20:50:10 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@ShadowDzz/featured
# [INFO] 2025-12-05 20:50:22 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@mayo_sha/about
# [ERROR] 2025-12-05 20:50:22 - selenium_utils_COMPLETE - [ERROR] Failed to click element: Message:
#
# [INFO] 2025-12-05 20:50:23 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@Dapokir_Trendismer/about
# [INFO] 2025-12-05 20:50:34 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@ShadowDzz/about
# [INFO] 2025-12-05 20:50:34 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 0 links from https://www.youtube.com/@mayo_sha
# [INFO] 2025-12-05 20:50:37 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 20:50:37 - WDM - ====== WebDriver manager ======
# [INFO] 2025-12-05 20:50:37 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 3 links from https://www.youtube.com/@ShadowDzz
# [INFO] 2025-12-05 20:50:37 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 0 links from https://www.youtube.com/@Dapokir_Trendismer
# [INFO] 2025-12-05 20:50:38 - WDM - Get LATEST chromedriver version for google-chrome
# [INFO] 2025-12-05 20:50
- selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@FaresTw/featured
# [INFO] 2025-12-05 21:07:36 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@AfrikaBlacklabelTV/about
# [INFO] 2025-12-05 21:07:49 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 0 links from https://www.youtube.com/@AfrikaBlacklabelTV
# [INFO] 2025-12-05 21:07:51 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 21:08:00 - selenium_utils_COMPLETE - [INFO] Navigating to https://www.youtube.com/@FaresTw/about
# [INFO] 2025-12-05 21:08:03 - youtube_scraper_COMPLETE_FIXED - [OK] Extracted 1 links from https://www.youtube.com/@FaresTw
# [INFO] 2025-12-05 21:08:05 - selenium_utils_COMPLETE - [OK] Driver closed
# [INFO] 2025-12-05 21:08:05 - youtube_scraper_COMPLETE_FIXED - [OK] Link extraction completed! Total links found: 209
# [OK] Link extraction completed!
# [INFO] Total links found: 209

# %% [markdown]
# ## Step 4: View Raw Results
#
# Show the raw extracted results.

# %%
# Show raw results
df_raw = pd.DataFrame(all_results)

print("Raw Results (first 15 rows):")
print(df_raw.head(15).to_string(index=False))

# Count by platform
print("\nLinks by Platform:")
platform_counts = df_raw['platform'].value_counts()
for platform, count in platform_counts.items():
    print(f"  {platform}: {count}")
# Out:
# Raw Results (first 15 rows):
#                              channel_url        platform                                                           url
#    https://www.youtube.com/@CallMePearlX          TikTok  https://www.tiktok.com/@callmepearlxd?_t=ZN-8zcMwKT5zQk&_r=1
# https://www.youtube.com/@dzairtubetv4557        Telegram                                             t.me/dzairtube_tv
# https://www.youtube.com/@dzairtubetv4557        Facebook                            https://www.facebook.com/Dzairtube
# https://www.youtube.com/@dzairtubetv4557     X (Twitter)                                      https://x.com/dzair_tube
#     https://www.youtube.com/@BilalFadili       Instagram                      https://www.instagram.com/bilal_fadilii/
#     https://www.youtube.com/@BilalFadili          TikTok                          https://www.tiktok.com/@bilalfadilii
#     https://www.youtube.com/@BilalFadili       Instagram                      https://www.instagram.com/bilal_fadilii/
#     https://www.youtube.com/@BilalFadili          TikTok                          https://www.tiktok.com/@bilalfadilii
#  https://www.youtube.com/@AfinouGamingDZ YouTube Channel https://www.youtube.com/channel/UCXYZT0LaqUaseOlWXMS5j7w/join
#  https://www.youtube.com/@AfinouGamingDZ       Instagram                     https://www.instagram.com/afinoudz/?hl=fr
#  https://www.youtube.com/@AfinouGamingDZ          TikTok                      https://www.tiktok.com/@afinoudz?lang=fr
#  https://www.youtube.com/@AfinouGamingDZ        Facebook              https://www.facebook.com/groups/634252724084794/
#  https://www.youtube.com/@AfinouGamingDZ YouTube Channel https://www.youtube.com/channel/UCXYZT0LaqUaseOlWXMS5j7w/join
#  https://www.youtube.com/@AfinouGamingDZ       Instagram                           https://www.instagram.com/afinoudz/
#  https://www.youtube.com/@AfinouGamingDZ          TikTok                      https://www.tiktok.com/@afinoudz?lang=fr
#
# Links by Platform:
#   Instagram: 64
#   YouTube Channel: 37
#   Facebook: 32
#   TikTok: 24
#   X (Twitter): 19
#   Discord: 16
#   Email: 14
#   Snapchat: 2
#   Telegram: 1

# %% [markdown]
# ## Step 5: Pivot Data
#
# Transform the data so each row = one channel with columns for each social media platform.
# This makes it easier to analyze and use.

# %%
# Pivot the data
df_pivot = DataProcessor.pivot_social_links(all_results)

print("Pivoted Results (first 10 channels):")
print(df_pivot.head(10).to_string())

print(f"\n[OK] Pivoted {len(df_pivot)} unique channels")
print(f"[INFO] Columns: {', '.join(df_pivot.columns.tolist())}")
# Out:
# [INFO] 2025-12-05 21:13:25 - data_processor_COMPLETE_FIXED - [OK] Pivoted 44 unique channels
# Pivoted Results (first 10 channels):
# platform                              channel_url                        Discord                                 Email                                                                 Facebook                                             Instagram                                  Snapchat Telegram                                                        TikTok                                             X (Twitter)                                                              YouTube Channel
# 0            https://www.youtube.com/@Aba.Stories                            NaN                                   NaN  https://www.facebook.com/profile.php?id=100076107540978&mibextid=LQQJ4d  https://instagram.com/aba.storie?igshid=YmMyMTA2M2Y=  https://www.snapchat.com/add/aba.stories      NaN       https://www.tiktok.com/@aba.stories?_t=8bm6plEz5ba&_r=1  https://x.com/abastories?s=21&t=T5es4zPlq0-dHhUFkxcRbQ                                                                          NaN
# 1            https://www.youtube.com/@Abousajed10                            NaN      https://youtube.com/@Abousajed10  https://www.facebook.com/profile.php?id=100083192415600&mibextid=ZbWKwL         https://www.instagram.com/matbkh_abou_sadjed/                                       NaN      NaN                                                           NaN                                                     NaN                                                                          NaN
# 2         https://www.youtube.com/@AfinouGamingDZ                            NaN                                   NaN                         https://www.facebook.com/groups/634252724084794/             https://www.instagram.com/afinoudz/?hl=fr                                       NaN      NaN                      https://www.tiktok.com/@afinoudz?lang=fr                                                     NaN                https://www.youtube.com/channel/UCXYZT0LaqUaseOlWXMS5j7w/join
# 3           https://www.youtube.com/@AniMugen2048                            NaN                                   NaN                                                                      NaN                                                   NaN                                       NaN      NaN                                                           NaN                                                     NaN                                      https://www.youtube.com/c/@AniMugen2048
# 4            https://www.youtube.com/@Anisgamer23  https://discord.gg/YSay6eWCbG  https://www.youtube.com/@Anisgamer23                                                                      NaN           https://www.instagram.com/mohamed_mehailla/                                       NaN      NaN                           https://www.tiktok.com/@anisgamer23                                                     NaN              https://www.youtube.com/channel/UCw4-7xEOFdCkM-K7FD6sSBA/videos
# 5            https://www.youtube.com/@BilalFadili                            NaN                                   NaN                                                                      NaN              https://www.instagram.com/bilal_fadilii/                                       NaN      NaN                          https://www.tiktok.com/@bilalfadilii                                                     NaN                                                                          NaN
# 6           https://www.youtube.com/@CallMePearlX                            NaN                                   NaN                                                                      NaN                                                   NaN                                       NaN      NaN  https://www.tiktok.com/@callmepearlxd?_t=ZN-8zcMwKT5zQk&_r=1                                                     NaN                                                                          NaN
# 7             https://www.youtube.com/@DZ_PLAYER_  https://discord.gg/j5F6DZAnvm                                   NaN                                                                      NaN                                                   NaN                                       NaN      NaN                                                           NaN                                                     NaN                                                                          NaN
# 8               https://www.youtube.com/@DZlegend  https://discord.gg/ds9NMhQUPj                                   NaN                                   https://www.facebook.com/youtubelegend                 https://www.instagram.com/dzlegendyt/                                       NaN      NaN                                                           NaN                         https://twitter.com/TheDZlegend  https://www.youtube.com/channel/UCeitzfgqHGVJnPOE8GoxPWg?sub_confirmation=1
# 9            https://www.youtube.com/@Dhiaagaming  https://discord.gg/TtmVaj7U89                                   NaN                                                                      NaN               https://www.instagram.com/dhiaa.gaming/                                       NaN      NaN                          https://www.tiktok.com/@dhiaagaming0                                                     NaN                                                                          NaN
#
# [OK] Pivoted 44 unique channels
# [INFO] Columns: channel_url, Discord, Email, Facebook, Instagram, Snapchat, Telegram, TikTok, X (Twitter), YouTube Channel

# %% [markdown]
# ## Step 6: Save Results
#
# Save results in both raw and pivoted formats.

# %%
# Save results in both formats

# Format 1: Raw data (all links)
raw_output = "socialmedialinks_raw.xlsx"
DataProcessor.save_results(all_results, raw_output)

# Format 2: Pivoted data (one row per channel)
pivoted_output = "socialmedialinks_pivoted.xlsx"
pivot_path = Path.cwd() / 'data' / 'processed' / pivoted_output
pivot_path.parent.mkdir(parents=True, exist_ok=True)
df_pivot.to_excel(pivot_path, index=False, engine='openpyxl')

print(f"[OK] Pivoted results saved to {pivot_path}")

print("\n[OK] Output files created:")
print(f"  1. {raw_output} (raw format - all links)")
print(f"  2. {pivoted_output} (pivoted format - RECOMMENDED for analysis)")
# Out:
# [INFO] 2025-12-05 21:13:27 - data_processor_COMPLETE_FIXED - [OK] Saved 209 results to data\processed\socialmedialinks_raw.xlsx
# [OK] Pivoted results saved to C:\Users\ArabTech\02_youtube_channel_scraper\src\data\processed\socialmedialinks_pivoted.xlsx
#
# [OK] Output files created:
#   1. socialmedialinks_raw.xlsx (raw format - all links)
#   2. socialmedialinks_pivoted.xlsx (pivoted format - RECOMMENDED for analysis)

# %% [markdown]
# ## Step 7: Summary Statistics
#
# Generate summary statistics about the extracted links.

# %%
# Generate summary statistics
print("Summary Statistics")
print("=" * 50)

# Channels with links
channels_with_links = df_pivot.iloc[:, 1:].notna().sum(axis=1).sum()
channels_total = len(df_pivot)
channels_with_no_links = df_pivot.iloc[:, 1:].isna().all(axis=1).sum()

print(f"Total channels processed: {channels_total}")
print(f"Channels with links: {channels_total - channels_with_no_links}")
print(f"Channels with no links: {channels_with_no_links}")

print("\nLinks found by platform:")
for col in df_pivot.columns[1:]:
    count = df_pivot[col].notna().sum()
    print(f"  {col}: {count}")

print(f"\n[OK] Next step: Run Notebook 03 to get engagement metrics!")
# Out:
# Summary Statistics
# ==================================================
# Total channels processed: 44
# Channels with links: 44
# Channels with no links: 0
#
# Links found by platform:
#   Discord: 12
#   Email: 12
#   Facebook: 21
#   Instagram: 28
#   Snapchat: 2
#   Telegram: 1
#   TikTok: 16
#   X (Twitter): 14
#   YouTube Channel: 14
#
# [OK] Next step: Run Notebook 03 to get engagement metrics!

# %% [markdown]
# ## Summary
#
# You now have social media links extracted from all channels!
#
# ### Files Created:
# - `socialmedialinks_raw.xlsx` - All extracted links
# - `socialmedialinks_pivoted.xlsx` - One row per channel (recommended)
#
# ### Next Steps:
# 1. ✅ Run **Notebook 03** to get engagement metrics
# 2. Optional: Review the Excel files to verify link accuracy
# 3. Optional: Create visualizations based on the data
